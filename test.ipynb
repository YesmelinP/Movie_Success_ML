# %%
# Dependencies
import requests
import json
from config import YOUR_API_KEY

url = f'https://api.watchmode.com/v1/networks/?apiKey={YOUR_API_KEY}'
list_titles_api = f'https://api.watchmode.com/v1/list-titles/?apiKey={YOUR_API_KEY}&source_ids=203,57'
releases_api = f'https://api.watchmode.com/v1/releases/?apiKey={YOUR_API_KEY}'

# %%
print(requests.get(releases_api))
# Out:
# <Response [200]>

# %%
print(releases_api)
print(url)
print(list_titles_api)
# Out:
# https://api.watchmode.com/v1/releases/?apiKey=5YG8EtS7qPoYkgeqNGlw6URYw4ggWbylXQj6KfXD
# https://api.watchmode.com/v1/networks/?apiKey=5YG8EtS7qPoYkgeqNGlw6URYw4ggWbylXQj6KfXD
# https://api.watchmode.com/v1/list-titles/?apiKey=5YG8EtS7qPoYkgeqNGlw6URYw4ggWbylXQj6KfXD&source_ids=203,57

# %%
print(requests.get(releases_api).json())
# Out:
# {'releases': [{'id': 1847517, 'title': 'Untold: Hope Solo vs. U.S. Soccer', 'type': 'movie', 'imdb_id': 'tt33043060', 'tmdb_id': 1324990, 'tmdb_type': 'movie', 'season_number': None, 'poster_url': 'https://cdn.watchmode.com/posters/01847517_poster_w185.jpg', 'source_release_date': '2024-09-03', 'source_id': 203, 'source_name': 'Netflix', 'is_original': 0}, {'id': 3182385, 'title': 'Last One Standing', 'type': 'tv_series', 'imdb_id': 'tt18246842', 'tmdb_id': 157926, 'tmdb_type': 'tv', 'season_number': 3, 'poster_url': 'https://cdn.watchmode.com/posters/03182385_poster_w185.jpg', 'source_release_date': '2024-09-03', 'source_id': 203, 'source_name': 'Netflix', 'is_original': 1}, {'id': 549840, 'title': 'Phil Wang: Wang in There, Baby!', 'type': 'tv_special', 'imdb_id': 'tt33088662', 'tmdb_id': 1336863, 'tmdb_type': 'movie', 'season_number': None, 'poster_url': 'https://cdn.watchmode.com/posters/0549840_poster_w185.jpg', 'source_release_date': '2024-09-03', 'source_id': 203, 'source_name
# ...

# %%
response = requests.get(releases_api).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "releases": [
#         {
#             "id": 1847517,
#             "imdb_id": "tt33043060",
#             "is_original": 0,
#             "poster_url": "https://cdn.watchmode.com/posters/01847517_poster_w185.jpg",
#             "season_number": null,
#             "source_id": 203,
#             "source_name": "Netflix",
#             "source_release_date": "2024-09-03",
#             "title": "Untold: Hope Solo vs. U.S. Soccer",
#             "tmdb_id": 1324990,
#             "tmdb_type": "movie",
#             "type": "movie"
#         },
#         {
#             "id": 3182385,
#             "imdb_id": "tt18246842",
#             "is_original": 1,
#             "poster_url": "https://cdn.watchmode.com/posters/03182385_poster_w185.jpg",
#             "season_number": 3,
#             "source_id": 203,
#             "source_name": "Netflix",
#             "source_release_date": "2024-09-03",
#             "title": "Last One Standing",
#             "tmdb_id": 157926,
# ...

# %%
# releases_data = 
#    {
#       "id": 1847517,
#       "title": "Untold: Hope Solo vs. U.S. Soccer",
#       "type": "movie",
#       "imdb_id": "tt33043060",
#       "tmdb_id": 1324990,
#       "tmdb_type": "movie",
#       "season_number": null,
#       "poster_url": "https://cdn.watchmode.com/posters/01847517_poster_w185.jpg",
#       "source_release_date": "2024-09-03",
#       "source_id": 203,
#       "source_name": "Netflix",
#       "is_original": 0
#     },


# titles = 
#  {
#       "id": 1634575,
#       "title": "The Killer",
#       "year": 2023,
#       "imdb_id": "tt1136617",
#       "tmdb_id": 800158,
#       "tmdb_type": "movie",
#       "type": "movie"
#     },


# networks = 

# {
#     "id": 1,
#     "name": "HBO",
#     "origin_country": "US",
#     "tmdb_id": 49
#   },
